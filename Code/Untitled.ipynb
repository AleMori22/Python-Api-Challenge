# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city

city_data = []

city_data_df = pd.DataFrame(columns=["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"])

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
   
    # Create endpoint URL with each city
    city_url = f'{url}q={city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        
        city_data.append({
            "City": city,
            "Lat": city_weather['coord']['lat'],
            "Lng": city_weather['coord']['lon'],
            "Max Temp": city_weather['main']['temp_max'],
            "Humidity": city_weather['main']['humidity'],
            "Cloudiness": city_weather['clouds']['all'],
            "Wind Speed": city_weather['wind']['speed'],
            "Country": city_weather['sys']['country'],
            "Date": city_weather['dt']})
       
    
    
    # Append the City information into city_data list
        
         
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
 #Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | olonkinbyen
# Processing Record 3 of Set 1 | stanley
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | frontera
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | morehead city
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | whitehorse
# Processing Record 12 of Set 1 | port douglas
# Processing Record 13 of Set 1 | vorkuta
# Processing Record 14 of Set 1 | cidade velha
# Processing Record 15 of Set 1 | minas de marcona
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | college
# Processing Record 18 of Set 1 | crane
# Processing Record 19 of Set 1 | aasiaat
# Processing Record 20 of Set 1 | nishinoomote
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | bandon
# Processing Record 25 of Set 1 | panitian
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | la passe
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | orsk
# Processing Record 31 of Set 1 | rio grande
# Processing Record 32 of Set 1 | maputo
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | smithers
# Processing Record 35 of Set 1 | wusong
# Processing Record 36 of Set 1 | agapovka
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | plastun
# Processing Record 40 of Set 1 | harper
# Processing Record 41 of Set 1 | dubbo
# Processing Record 42 of Set 1 | adamstown
# Processing Record 43 of Set 1 | kone
# Processing Record 44 of Set 1 | mili
# Processing Record 45 of Set 1 | waitangi
# Processing Record 46 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | great bend
# Processing Record 50 of Set 1 | san pedro pochutla
# Processing Record 0 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | kapuskasing
# Processing Record 4 of Set 2 | invercargill
# Processing Record 5 of Set 2 | keren
# Processing Record 6 of Set 2 | afaahiti
# Processing Record 7 of Set 2 | beloyarskiy
# Processing Record 8 of Set 2 | egilsstadir
# Processing Record 9 of Set 2 | isafjordur
# Processing Record 10 of Set 2 | northam
# Processing Record 11 of Set 2 | fuglafjordur
# Processing Record 12 of Set 2 | kroya
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | ust'-ilimsk
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | iskateley
# Processing Record 19 of Set 2 | enewetak
# Processing Record 20 of Set 2 | hun
# Processing Record 21 of Set 2 | agropoli
# Processing Record 22 of Set 2 | margaret river
# Processing Record 23 of Set 2 | san rafael
# Processing Record 24 of Set 2 | constitucion
# Processing Record 25 of Set 2 | isangel
# Processing Record 26 of Set 2 | nicoya
# Processing Record 27 of Set 2 | atafu village
# Processing Record 28 of Set 2 | wailua homesteads
# Processing Record 29 of Set 2 | palikir - national government center
# Processing Record 30 of Set 2 | acarau
# Processing Record 31 of Set 2 | pansemal
# Processing Record 32 of Set 2 | newman
# Processing Record 33 of Set 2 | fale old settlement
# Processing Record 34 of Set 2 | tanjungbalai
# Processing Record 35 of Set 2 | praia da vitoria
# Processing Record 36 of Set 2 | okahao
# Processing Record 37 of Set 2 | were ilu
# Processing Record 38 of Set 2 | tazovsky
# Processing Record 39 of Set 2 | krasnyy chikoy
# Processing Record 40 of Set 2 | klyuchi
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | sanctuary point
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | worland
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | diveyevo
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | lugovoye
# Processing Record 0 of Set 3 | xilin hot
# Processing Record 1 of Set 3 | puerto de la cruz
# Processing Record 2 of Set 3 | northwood
# Processing Record 3 of Set 3 | san mariano
# Processing Record 4 of Set 3 | anaconda
# Processing Record 5 of Set 3 | naze
# Processing Record 6 of Set 3 | honefoss
# Processing Record 7 of Set 3 | hastings
# Processing Record 8 of Set 3 | barcelos
# Processing Record 9 of Set 3 | solnechnyy
# Processing Record 10 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 11 of Set 3 | thunder bay
# Processing Record 12 of Set 3 | vorgashor
# Processing Record 13 of Set 3 | remire-montjoly
# Processing Record 14 of Set 3 | cadale
# Processing Record 15 of Set 3 | sao geraldo do araguaia
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | kotka
# Processing Record 19 of Set 3 | mahibadhoo
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | anadyr
# Processing Record 22 of Set 3 | hwacheon
# Processing Record 23 of Set 3 | aral
# Processing Record 24 of Set 3 | kolwezi
# Processing Record 25 of Set 3 | lewistown
# Processing Record 26 of Set 3 | sovetsk
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | santa cruz
# Processing Record 30 of Set 3 | the pas
# Processing Record 31 of Set 3 | gobichettipalayam
# Processing Record 32 of Set 3 | hawaiian paradise park
# Processing Record 33 of Set 3 | tazacorte
# Processing Record 34 of Set 3 | uddevalla
# Processing Record 35 of Set 3 | hammerfest
# Processing Record 36 of Set 3 | novaya mayna
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | nova sintra
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | moengo
# Processing Record 41 of Set 3 | sao vicente
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | sinabang
# Processing Record 44 of Set 3 | angaur state
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | hadibu
# Processing Record 47 of Set 3 | kahama
# Processing Record 48 of Set 3 | ebon
# Processing Record 49 of Set 3 | dunedin
# Processing Record 0 of Set 4 | divino das laranjeiras
# Processing Record 1 of Set 4 | melfi
# Processing Record 2 of Set 4 | fort-shevchenko
# Processing Record 3 of Set 4 | ceerigaabo
# Processing Record 4 of Set 4 | gobabis
# Processing Record 5 of Set 4 | vastaboland
# City not found. Skipping...
# Processing Record 6 of Set 4 | alpena
# Processing Record 7 of Set 4 | udachny
# Processing Record 8 of Set 4 | woolgoolga
# Processing Record 9 of Set 4 | spring
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | vadso
# Processing Record 12 of Set 4 | presidente epitacio
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | caluula
# Processing Record 15 of Set 4 | nchelenge
# Processing Record 16 of Set 4 | slobodskoy
# Processing Record 17 of Set 4 | toguchin
# Processing Record 18 of Set 4 | troitsko-pechorsk
# Processing Record 19 of Set 4 | sanandaj
# Processing Record 20 of Set 4 | kapa'a
# Processing Record 21 of Set 4 | pasuquin
# Processing Record 22 of Set 4 | khandyga
# Processing Record 23 of Set 4 | nantucket
# Processing Record 24 of Set 4 | murghob
# Processing Record 25 of Set 4 | lazaro cardenas
# Processing Record 26 of Set 4 | al kharijah
# Processing Record 27 of Set 4 | road town
# Processing Record 28 of Set 4 | sao jose do belmonte
# Processing Record 29 of Set 4 | mangrol
# Processing Record 30 of Set 4 | minacu
# City not found. Skipping...
# Processing Record 31 of Set 4 | tanjung selor
# City not found. Skipping...
# Processing Record 32 of Set 4 | belyy yar
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | mount pearl
# Processing Record 35 of Set 4 | port saint john's
# Processing Record 36 of Set 4 | badger
# Processing Record 37 of Set 4 | eraan
# Processing Record 38 of Set 4 | posto fiscal rolim de moura
# Processing Record 39 of Set 4 | porto novo
# Processing Record 40 of Set 4 | pauillac
# Processing Record 41 of Set 4 | atar
# Processing Record 42 of Set 4 | suva
# Processing Record 43 of Set 4 | torteval
# City not found. Skipping...
# Processing Record 44 of Set 4 | shimoda
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | dudinka
# Processing Record 48 of Set 4 | itoman
# Processing Record 49 of Set 4 | zima
# Processing Record 0 of Set 5 | punta arenas
# Processing Record 1 of Set 5 | namtsy
# Processing Record 2 of Set 5 | clovis
# Processing Record 3 of Set 5 | martuk
# Processing Record 4 of Set 5 | kodinsk
# Processing Record 5 of Set 5 | trenggalek
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | mount isa
# Processing Record 8 of Set 5 | ola
# Processing Record 9 of Set 5 | margate
# Processing Record 10 of Set 5 | saipan
# Processing Record 11 of Set 5 | vilyuchinsk
# Processing Record 12 of Set 5 | mejit
# Processing Record 13 of Set 5 | kartuzy
# Processing Record 14 of Set 5 | den chai
# Processing Record 15 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 16 of Set 5 | makoua
# Processing Record 17 of Set 5 | azna
# Processing Record 18 of Set 5 | murzuq
# Processing Record 19 of Set 5 | saratamata
# City not found. Skipping...
# Processing Record 20 of Set 5 | newnham
# Processing Record 21 of Set 5 | kumeny
# Processing Record 22 of Set 5 | cootamundra
# Processing Record 23 of Set 5 | awjilah
# Processing Record 24 of Set 5 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 25 of Set 5 | gorgan
# Processing Record 26 of Set 5 | princeville
# Processing Record 27 of Set 5 | padra
# Processing Record 28 of Set 5 | aleksandrovsk-sakhalinskiy
# Processing Record 29 of Set 5 | tolanaro
# Processing Record 30 of Set 5 | bafq
# Processing Record 31 of Set 5 | chernyshevskiy
# Processing Record 32 of Set 5 | at taj
# Processing Record 33 of Set 5 | chibougamau
# Processing Record 34 of Set 5 | fonadhoo
# City not found. Skipping...
# Processing Record 35 of Set 5 | tsiombe
# Processing Record 36 of Set 5 | fort wellington
# Processing Record 37 of Set 5 | weno
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | goz beida
# Processing Record 40 of Set 5 | baardheere
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | el granada
# Processing Record 43 of Set 5 | arkhangel'sk
# Processing Record 44 of Set 5 | howard springs
# Processing Record 45 of Set 5 | moyynkum
# Processing Record 46 of Set 5 | kerikeri
# Processing Record 47 of Set 5 | st. john's
# Processing Record 48 of Set 5 | qarazhal
# Processing Record 49 of Set 5 | clorinda
# Processing Record 0 of Set 6 | tual
# Processing Record 1 of Set 6 | amga
# Processing Record 2 of Set 6 | qaqortoq
# Processing Record 3 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 6 | santa marta de ortigueira
# Processing Record 5 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 6 | port mathurin
# Processing Record 7 of Set 6 | ladnun
# Processing Record 8 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 9 of Set 6 | cochem
# Processing Record 10 of Set 6 | gilgit
# Processing Record 11 of Set 6 | simplicio mendes
# Processing Record 12 of Set 6 | misratah
# Processing Record 13 of Set 6 | kenora
# Processing Record 14 of Set 6 | lethem
# Processing Record 15 of Set 6 | wamba
# Processing Record 16 of Set 6 | bonthe
# Processing Record 17 of Set 6 | ilulissat
# Processing Record 18 of Set 6 | kouvola
# Processing Record 19 of Set 6 | zinjibar
# Processing Record 20 of Set 6 | kununurra
# Processing Record 21 of Set 6 | concepcion del uruguay
# Processing Record 22 of Set 6 | rosetta
# Processing Record 23 of Set 6 | zheleznodorozhnyy
# Processing Record 24 of Set 6 | constantia
# Processing Record 25 of Set 6 | bereeda
# Processing Record 26 of Set 6 | chonchi
# Processing Record 27 of Set 6 | novomikhaylovskiy
# Processing Record 28 of Set 6 | prince rupert
# Processing Record 29 of Set 6 | porto barra do ivinheima
# Processing Record 30 of Set 6 | queenstown
# Processing Record 31 of Set 6 | batam
# City not found. Skipping...
# Processing Record 32 of Set 6 | malango
# Processing Record 33 of Set 6 | moree
# Processing Record 34 of Set 6 | dungarpur
# Processing Record 35 of Set 6 | haldibari
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | nizhniy kuranakh
# Processing Record 38 of Set 6 | buta
# Processing Record 39 of Set 6 | khorramabad
# Processing Record 40 of Set 6 | kourou
# Processing Record 41 of Set 6 | porto seguro
# Processing Record 42 of Set 6 | bodo
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | fort st. john
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | dolisie
# Processing Record 48 of Set 6 | mount gambier
# Processing Record 49 of Set 6 | lira
# Processing Record 0 of Set 7 | charters towers
# Processing Record 1 of Set 7 | tevragh zeina
# City not found. Skipping...
# Processing Record 2 of Set 7 | ratnapura
# Processing Record 3 of Set 7 | cedeira
# Processing Record 4 of Set 7 | san luis de la loma
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | nemuro
# Processing Record 7 of Set 7 | hegang
# Processing Record 8 of Set 7 | pingxiang
# Processing Record 9 of Set 7 | padang
# Processing Record 10 of Set 7 | male
# Processing Record 11 of Set 7 | guapo
# Processing Record 12 of Set 7 | contamana
# Processing Record 13 of Set 7 | kidal
# Processing Record 14 of Set 7 | adiake
# Processing Record 15 of Set 7 | horta
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | odda
# Processing Record 19 of Set 7 | ust-nera
# Processing Record 20 of Set 7 | strezhevoy
# Processing Record 21 of Set 7 | abadeh
# Processing Record 22 of Set 7 | morondava
# Processing Record 23 of Set 7 | utrik
# Processing Record 24 of Set 7 | la ronge
# Processing Record 25 of Set 7 | severo-yeniseyskiy
# Processing Record 26 of Set 7 | hosa'ina
# City not found. Skipping...
# Processing Record 27 of Set 7 | sao jose da coroa grande
# Processing Record 28 of Set 7 | port shepstone
# Processing Record 29 of Set 7 | felege neway
# Processing Record 30 of Set 7 | inirida
# Processing Record 31 of Set 7 | port macquarie
# Processing Record 32 of Set 7 | cururupu
# Processing Record 33 of Set 7 | callao
# Processing Record 34 of Set 7 | lalibela
# Processing Record 35 of Set 7 | flying fish cove
# Processing Record 36 of Set 7 | revelstoke
# Processing Record 37 of Set 7 | tubarjal
# Processing Record 38 of Set 7 | sangin
# Processing Record 39 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 40 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 7 | buxton
# Processing Record 42 of Set 7 | enkhuizen
# Processing Record 43 of Set 7 | malkara
# Processing Record 44 of Set 7 | la'ie
# Processing Record 45 of Set 7 | trincomalee
# Processing Record 46 of Set 7 | konarka
# Processing Record 47 of Set 7 | calca
# Processing Record 48 of Set 7 | tongren
# Processing Record 49 of Set 7 | gadzhiyevo
# Processing Record 0 of Set 8 | puerto deseado
# Processing Record 1 of Set 8 | quatre cocos
# Processing Record 2 of Set 8 | den burg
# Processing Record 3 of Set 8 | bojia
# Processing Record 4 of Set 8 | khash
# Processing Record 5 of Set 8 | nizhneangarsk
# Processing Record 6 of Set 8 | fisterra
# Processing Record 7 of Set 8 | vil'ne
# Processing Record 8 of Set 8 | nayoro
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | arsen'yev
# Processing Record 11 of Set 8 | la palma
# Processing Record 12 of Set 8 | papao
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | hinton
# Processing Record 15 of Set 8 | mhamid
# Processing Record 16 of Set 8 | peace river
# Processing Record 17 of Set 8 | puerto colombia
# Processing Record 18 of Set 8 | carnarvon
# Processing Record 19 of Set 8 | santa ana de yacuma
# Processing Record 20 of Set 8 | urangan
# Processing Record 21 of Set 8 | gorontalo
# Processing Record 22 of Set 8 | ryotsu-minato
# Processing Record 23 of Set 8 | abatskoye
# Processing Record 24 of Set 8 | cabedelo
# Processing Record 25 of Set 8 | haapsalu
# Processing Record 26 of Set 8 | vernon
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | ponta delgada
# Processing Record 29 of Set 8 | pizarro
# Processing Record 30 of Set 8 | chabahar
# Processing Record 31 of Set 8 | san juan de miraflores
# Processing Record 32 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 8 | obuase
# Processing Record 34 of Set 8 | oktyabr'sk
# Processing Record 35 of Set 8 | aden
# Processing Record 36 of Set 8 | khanty-mansiysk
# Processing Record 37 of Set 8 | zapala
# Processing Record 38 of Set 8 | vila do maio
# Processing Record 39 of Set 8 | ulladulla
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | tari
# Processing Record 42 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 43 of Set 8 | korla
# Processing Record 44 of Set 8 | castillos
# Processing Record 45 of Set 8 | sheboygan
# Processing Record 46 of Set 8 | aykhal
# Processing Record 47 of Set 8 | tokar
# Processing Record 48 of Set 8 | thames
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 0 of Set 9 | brisas de zicatela
# Processing Record 1 of Set 9 | georgetown
# Processing Record 2 of Set 9 | buka
# Processing Record 3 of Set 9 | rupea
# Processing Record 4 of Set 9 | arrecife
# Processing Record 5 of Set 9 | fortuna
# Processing Record 6 of Set 9 | baranchinskiy
# Processing Record 7 of Set 9 | mokokchung
# Processing Record 8 of Set 9 | mantua
# Processing Record 9 of Set 9 | nurota
# Processing Record 10 of Set 9 | rapid city
# Processing Record 11 of Set 9 | bishoftu
# Processing Record 12 of Set 9 | saarijarvi
# Processing Record 13 of Set 9 | grand-bassam
# Processing Record 14 of Set 9 | al-`ula
# City not found. Skipping...
# Processing Record 15 of Set 9 | colonia
# Processing Record 16 of Set 9 | puerto aysen
# Processing Record 17 of Set 9 | sur
# Processing Record 18 of Set 9 | kailua-kona
# Processing Record 19 of Set 9 | zaozersk
# Processing Record 20 of Set 9 | camana
# Processing Record 21 of Set 9 | lihue
# Processing Record 22 of Set 9 | kolyvan'
# Processing Record 23 of Set 9 | lycksele
# Processing Record 24 of Set 9 | ugoofaaru
# Processing Record 25 of Set 9 | tobruk
# Processing Record 26 of Set 9 | samarra'
# City not found. Skipping...
# Processing Record 27 of Set 9 | fort bragg
# Processing Record 28 of Set 9 | akureyri
# Processing Record 29 of Set 9 | kamloops
# Processing Record 30 of Set 9 | tchaourou
# Processing Record 31 of Set 9 | ignalina
# Processing Record 32 of Set 9 | camacupa
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | grafton
# Processing Record 35 of Set 9 | bikenibeu village
# Processing Record 36 of Set 9 | igarka
# Processing Record 37 of Set 9 | nichinan
# Processing Record 38 of Set 9 | gargalianoi
# Processing Record 39 of Set 9 | dryden
# Processing Record 40 of Set 9 | touros
# Processing Record 41 of Set 9 | santa ana
# Processing Record 42 of Set 9 | essaouira
# Processing Record 43 of Set 9 | nyurba
# Processing Record 44 of Set 9 | burela de cabo
# Processing Record 45 of Set 9 | saint-pol-sur-ternoise
# Processing Record 46 of Set 9 | lejanias
# Processing Record 47 of Set 9 | guilin
# Processing Record 48 of Set 9 | ranot
# Processing Record 49 of Set 9 | ulsteinvik
# Processing Record 0 of Set 10 | meadow lakes
# Processing Record 1 of Set 10 | mercedes
# Processing Record 2 of Set 10 | port-vila
# Processing Record 3 of Set 10 | kosh-agach
# Processing Record 4 of Set 10 | ebaye
# Processing Record 5 of Set 10 | yangjiang
# Processing Record 6 of Set 10 | namibe
# Processing Record 7 of Set 10 | glendive
# Processing Record 8 of Set 10 | old orchard beach
# Processing Record 9 of Set 10 | opuwo
# Processing Record 10 of Set 10 | nadym
# Processing Record 11 of Set 10 | xining
# Processing Record 12 of Set 10 | kolonia
# Processing Record 13 of Set 10 | albu kamal
# Processing Record 14 of Set 10 | likiep
# Processing Record 15 of Set 10 | lamu
# Processing Record 16 of Set 10 | xingtai
# Processing Record 17 of Set 10 | sydney
# Processing Record 18 of Set 10 | bardai
# Processing Record 19 of Set 10 | manta
# Processing Record 20 of Set 10 | uturoa
# Processing Record 21 of Set 10 | revda
# Processing Record 22 of Set 10 | kansk
# Processing Record 23 of Set 10 | colonia menno
# Processing Record 24 of Set 10 | dalmatovo
# Processing Record 25 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 26 of Set 10 | pumiao
# Processing Record 27 of Set 10 | tejen
# Processing Record 28 of Set 10 | bani walid
# Processing Record 29 of Set 10 | martapura
# Processing Record 30 of Set 10 | yarmouth
# Processing Record 31 of Set 10 | senigallia
# Processing Record 32 of Set 10 | dingli
# Processing Record 33 of Set 10 | al hasakah
# Processing Record 34 of Set 10 | poplar bluff
# Processing Record 35 of Set 10 | bamboo flat
# Processing Record 36 of Set 10 | castlegar
# Processing Record 37 of Set 10 | smolensk
# Processing Record 38 of Set 10 | guiberoua
# Processing Record 39 of Set 10 | tantangan
# Processing Record 40 of Set 10 | cabagan
# Processing Record 41 of Set 10 | baoqing
# Processing Record 42 of Set 10 | malpe
# Processing Record 43 of Set 10 | hell-ville
# Processing Record 44 of Set 10 | cuito
# Processing Record 45 of Set 10 | sawakin
# Processing Record 46 of Set 10 | coahuayana de hidalgo
# Processing Record 47 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 10 | panjab
# Processing Record 49 of Set 10 | goundam
# Processing Record 0 of Set 11 | beipiao
# Processing Record 1 of Set 11 | mugia
# Processing Record 2 of Set 11 | cherepovets
# Processing Record 3 of Set 11 | hukumati azrah
# Processing Record 4 of Set 11 | sao borja
# Processing Record 5 of Set 11 | al jawf
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | nogliki
# Processing Record 8 of Set 11 | ausa
# Processing Record 9 of Set 11 | gao
# Processing Record 10 of Set 11 | makassar
# Processing Record 11 of Set 11 | ascencion
# Processing Record 12 of Set 11 | ras gharib
# City not found. Skipping...
# Processing Record 13 of Set 11 | okondja
# Processing Record 14 of Set 11 | puerto baquerizo moreno
# Processing Record 15 of Set 11 | masterton
# Processing Record 16 of Set 11 | guiuan
# Processing Record 17 of Set 11 | limon
# Processing Record 18 of Set 11 | chimbote
# Processing Record 19 of Set 11 | cuajinicuilapa
# Processing Record 20 of Set 11 | hoopstad
# Processing Record 21 of Set 11 | jinchang
# Processing Record 22 of Set 11 | hakui
# Processing Record 23 of Set 11 | kayangel
# Processing Record 24 of Set 11 | barah
# Processing Record 25 of Set 11 | port blair
# Processing Record 26 of Set 11 | castro de rei
# Processing Record 27 of Set 11 | negotin
# Processing Record 28 of Set 11 | dembi dolo
# Processing Record 29 of Set 11 | dombarovskiy
# Processing Record 30 of Set 11 | majene
# Processing Record 31 of Set 11 | sabha
# Processing Record 32 of Set 11 | mirpur sakro
# Processing Record 33 of Set 11 | rongelap
# Processing Record 34 of Set 11 | kunwi
# Processing Record 35 of Set 11 | taro
# Processing Record 36 of Set 11 | deschutes river woods
# Processing Record 37 of Set 11 | lerwick
# Processing Record 38 of Set 11 | labrador city
# Processing Record 39 of Set 11 | nova xavantina
# Processing Record 40 of Set 11 | kolonia town
# Processing Record 41 of Set 11 | carauari
# Processing Record 42 of Set 11 | holualoa
# Processing Record 43 of Set 11 | paciran
# Processing Record 44 of Set 11 | ribas do rio pardo
# Processing Record 45 of Set 11 | gazli
# Processing Record 46 of Set 11 | maffra
# Processing Record 47 of Set 11 | basco
# Processing Record 48 of Set 11 | fraile pintado
# Processing Record 49 of Set 11 | lapaha
# City not found. Skipping...
# Processing Record 0 of Set 12 | rutana
# Processing Record 1 of Set 12 | mogocha
# Processing Record 2 of Set 12 | greymouth
# Processing Record 3 of Set 12 | sterling
# Processing Record 4 of Set 12 | ibshaway
# Processing Record 5 of Set 12 | rawai
# Processing Record 6 of Set 12 | khuzdar
# Processing Record 7 of Set 12 | goshen
# Processing Record 8 of Set 12 | pasan
# Processing Record 9 of Set 12 | vitoria da conquista
# Processing Record 10 of Set 12 | hilton head island
# Processing Record 11 of Set 12 | san antonio de pale
# Processing Record 12 of Set 12 | al fqih ben calah
# Processing Record 13 of Set 12 | kashgar
# Processing Record 14 of Set 12 | mpika
# Processing Record 15 of Set 12 | xapuri
# Processing Record 16 of Set 12 | merizo village
# Processing Record 17 of Set 12 | houma
# Processing Record 18 of Set 12 | oodweyne
# Processing Record 19 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 12 | paola
# Processing Record 21 of Set 12 | eastham
# Processing Record 22 of Set 12 | ialibu
# Processing Record 23 of Set 12 | hoemul-li
# Processing Record 24 of Set 12 | pervomayskoye
# Processing Record 25 of Set 12 | hilo
# Processing Record 26 of Set 12 | yichun
# Processing Record 27 of Set 12 | ta`u
# Processing Record 28 of Set 12 | huocheng
# City not found. Skipping...
# Processing Record 29 of Set 12 | saint-joseph
# Processing Record 30 of Set 12 | wangaratta
# Processing Record 31 of Set 12 | okha
# Processing Record 32 of Set 12 | zhosaly
# Processing Record 33 of Set 12 | verkh-chebula
# Processing Record 34 of Set 12 | katiola
# Processing Record 35 of Set 12 | nanakuli
# Processing Record 36 of Set 12 | saynshand
# Processing Record 37 of Set 12 | sisimiut
# Processing Record 38 of Set 12 | east london
# Processing Record 39 of Set 12 | mwinilunga
# Processing Record 40 of Set 12 | antsiranana
# Processing Record 41 of Set 12 | valley city
# Processing Record 42 of Set 12 | chui
# Processing Record 43 of Set 12 | tralee
# Processing Record 44 of Set 12 | al bardiyah
# Processing Record 45 of Set 12 | orlovskiy
# Processing Record 46 of Set 12 | primero de mayo
# Processing Record 47 of Set 12 | cruzeiro do sul
# Processing Record 48 of Set 12 | szczecinek
# Processing Record 49 of Set 12 | salalah
# Processing Record 0 of Set 13 | bol'shoye murashkino
# Processing Record 1 of Set 13 | quellon
# Processing Record 2 of Set 13 | aykol
# City not found. Skipping...
# Processing Record 3 of Set 13 | ermelo
# Processing Record 4 of Set 13 | paoua
# Processing Record 5 of Set 13 | zhanaozen
# Processing Record 6 of Set 13 | kapit
# Processing Record 7 of Set 13 | jobabo
# Processing Record 8 of Set 13 | greenville
# Processing Record 9 of Set 13 | guerrero negro
# Processing Record 10 of Set 13 | tura
# Processing Record 11 of Set 13 | lorengau
# Processing Record 12 of Set 13 | rio gallegos
# Processing Record 13 of Set 13 | shalqar
# Processing Record 14 of Set 13 | villamontes
# Processing Record 15 of Set 13 | siguiri
# Processing Record 16 of Set 13 | jining
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data[0]
city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       kodiak  57.7900 -152.4072    278.88        87         100        7.20
# 1  olonkinbyen  70.9221   -8.7187    271.48        75         100        3.89
# 2      stanley  54.8680   -1.6985    278.02        95          75        4.12
# 3    grytviken -54.2811  -36.5092    274.51        65          23        5.27
# 4     thompson  55.7435  -97.8558    267.24        93         100        2.06
#
#   Country        Date
# 0      US  1701720111
# 1      SJ  1701720207
# 2      GB  1701720208
# 3      GS  1701719960
# 4      CA  1701720199
